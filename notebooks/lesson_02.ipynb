# %%
f = lambda x, y, z: x * 4.4382 + y * -8.4238 + z * -6.5720

# %%
1.8 - f(1.7, -2.2, 3.0)
# Out:
# -4.5613

# %%
2.8 - f(2.1, 1.9, -2.3)
# Out:
# -5.630600000000002

# %%
5.1 - f(4.2, 3.9, -3.1)
# Out:
# -1.0608200000000014
